# %%
import pandas as pd

# %%
from seaborn import heatmap

# %%
df = pd.read_csv("concat.csv", index_col=0)

# %%
df = df.subtract(df.min(axis=1), axis="rows")
df = df.divide(df.max(axis=1), axis="rows")

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 20]
plt.axis('scaled')
heatmap(df.T, 
        annot=True, cbar=False,  cmap="YlGnBu")
